# %%
# Initialize Otter
import otter
grader = otter.Notebook("KC1.ipynb")

# %%
import math

# %% [markdown]
# Before working on the Knowledge Check, make sure you **run the Python code cells at the top of the notebook**. These cells initialize the autograder and are required for the tests to work correctly.
#
# * If the first Python cell produces an error, try **restarting the kernel** by selecting **Kernel → Restart Kernel** from the JupyterLab menu.
# * After restarting the kernel, run the first Python cell again, followed by the remaining setup cells.
# * Make sure these setup cells run successfully before attempting the autograder tests.

# %% [markdown]
# # Knowledge Check 1

# %% [markdown]
# ## Due: Sep 03 by 11:59 pm

# %% [markdown]
# ## Instructions:
#
# 1. After completing **KC1**, download your completed `KC1.ipynb` file by selecting **File → Download** in JupyterLab.
#
# 2. Upload your completed `KC1.ipynb` file to the **KC1 Dropbox in D2L**.
#
# 3. This assignment is due by the **date and time listed in the course calendar**.
#
# 4. This is an **individual assignment**. As stated in the course syllabus, the use of AI tools is prohibited. You may not receive assistance from anyone other than the instructor, the TA, or the AARC. Any help received from the TA or AARC must be clearly documented.
#
# 5. If you use any resource other than the instructor or the course textbook, you must document it in a **new Markdown cell at the top of this notebook**. Include the source, what you learned from it, and specifically how you used that information in completing the assignment. Submissions that are copied, either partially or entirely, from another source will be subject to a significant penalty.
#
# 6. If you need help, visit the instructor during the posted office hours. If those times do not work with your schedule, email the instructor to arrange an alternative meeting time.
#
# 7. Passing the visible autograder tests does **not** guarantee that your answer is correct. The instructor may use additional hidden tests during grading. Full credit will be awarded only when your answers also pass these tests.
#
# 8. If you encounter any technical or assignment-related difficulties, please contact the instructor for assistance.
#
# 9. Reminder: If you successfully complete **at least 11 of the 13 Knowledge Checks (KCs)**, you will be eligible for **one additional opportunity to complete exam corrections**.

# %% [markdown]
# ### Learning Objectives
#
# By the end of this Knowledge Check, students should be able to:
#
# * Create and use **variables** to store values in Python.
# * Write and evaluate **expressions** involving variables and values.
# * Apply **numerical, Boolean, and comparison operators** in Python expressions.
# * Predict the results of expressions that combine multiple types of operators.
# * Identify common **Python errors** and explain why they occur.
# * Use **comments** appropriately to document and explain Python code.

# %% [markdown]
# # Core Skills

# %% [markdown]
# ### Question 1:
#
# Which of the following are valid Python variable names? Select __all__ that apply.
#
# A. student_name <br>
# B. 2nd_score <br>
# C. totalScore <br>
# D. class <br>
# E. final-grade <br>
# F. _average <br>
# G. score2 <br>
# H. student name <br>
#
# Hint: List of python reserved keywords can be found here: https://www.w3schools.com/python/python_ref_keywords.asp
#
# Read [Variables.ipynb](https://datascience2.sfasu.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fasvattha%2Fcsci1462_f26&urlpath=lab%2Ftree%2Fcsci1462_f26%2FLecture%2520Supplemental%2520Notes%2FVariables%2520and%2520Expressions&branch=main) to learn the rules for a valid python variable name.
#
# Write your options(separated by comma and no space) in the `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answers are option A, C, and E then your answer variable will look like `your_ans = "A,C,E"`

# %%
your_ans = ...

# %%
grader.check("q1")

# %% [markdown]
# ### Question 2:
#
# Create a variable, `uni_name` and store `STEPHEN F AUSTIN STATE UNIVERSITY` in it.

# %%
uni_name = ...

# %%
grader.check("q2")

# %% [markdown]
# ### Question 3:
#
# What is the value of `x` after the following code executes?
#
# ```
# x = 5
# x = x + 3
# ```
#
# Store your answer in the variable `your_ans`.

# %%
your_ans = ...

# %%
grader.check("q3")

# %% [markdown]
# ### Question 4:
#
# What is the value of `answer`?
#
# ```
# answer = (2 + 3) * 4
# ```
#
# Store your answer in the variable `your_ans`.

# %%
your_ans = ...

# %%
grader.check("q4")

# %% [markdown]
# ### Question 5:
#
# What is the value of x?
#
# ```
# x = 10 / 4
# ```
# A. 2 <br>
# B. 2.0 <br>
# C. 2.5 <br>
# D. 3 <br>
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`

# %%
your_ans = ...

# %%
grader.check("q5")

# %% [markdown]
# ### Question 6:
#
# What is the value of x?
#
# ```
# x = 10 // 4
# ```
# A. 4 <br>
# B. 2 <br>
# C. 2.5 <br>
# D. 3 <br>
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`

# %%
your_ans = ...

# %%
grader.check("q6")

# %% [markdown]
# ### Question 7:
#
# What is the value of remainder?
#
# ```
# remainder = 17 % 5
# ```
#
# Store your answer in the variable, `your_ans`.

# %%
your_ans = ...

# %%
grader.check("q7")

# %% [markdown]
# ### Question 8:
#
# What is printed?
#
# ```
# a = 5
# b = 2
# c = a ** b
#
# print(c)
# ```
#
# Store your answer in the variable `your_ans`.

# %%
your_ans = ...

# %%
grader.check("q8")

# %% [markdown]
# ### Question 9:
#
# What is the value of `result`?
#
# ```
# x = 10
# y = 7
#
# result = x > y
# ```
#
# A. 10 <br>
# B. 7 <br>
# C. True <br>
# D. False <br>
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`

# %%
your_ans = ...

# %%
grader.check("q9")

# %% [markdown]
# ### Question 10:
#
# What is printed?
#
# ```
# age = 20
# has_id = True
#
# print(age >= 18 and has_id)
# ```
#
# Store your answer in the variable `your_ans`.

# %%
your_ans = ...

# %%
grader.check("q10")

# %% [markdown]
# ### Question 11:
#
# What is printed?
# ```
# temperature = 95
# is_raining = False
#
# result = temperature > 90 or is_raining
# ```
# Store your answer in the variable `your_ans`.

# %%
your_ans = ...

# %%
grader.check("q11")

# %% [markdown]
# ### Question 12:
#
# What type of error occurs in the following code?
#
# ```
# print("Hello"
# ```
#
# A. TypeError <br>
# B. SyntaxError <br>
# C. NameError <br>
# D. ValueError <br>
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`

# %%
your_ans = ...

# %%
grader.check("q12")

# %% [markdown]
# ### Question 13:
#
# What happens when the following code runs?
# ```
# score = 90
# print(socre)
# ```
#
# A. Prints 90 <br>
# B. Prints socre <br>
# C. Causes a NameError <br>
# D. Causes a SyntaxError <br>
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`

# %%
your_ans = ...

# %%
grader.check("q13")

# %% [markdown]
# ### Question 14:
#
# What error occurs here?
#
# ```
# age = "20"
# next_age = age + 1
# ```
#
# A. SyntaxError  <br>
# B. TypeError <br>
# C. NameError <br>
# D. No error <br>
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`

# %%
your_ans = ...

# %%
grader.check("q14")

# %% [markdown]
# ### Question 15:
#
# Which of the following is a valid single-line comment in Python?
#
# A.
# `// Calculate total`
#
# B.
# `# Calculate total`
#
# C.
# `/* Calculate total */`
#
# D.
# `-- Calculate total`
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans` = "A"

# %%
your_ans = ...

# %%
grader.check("q15")

# %% [markdown]
# # Auxiliary Skills

# %% [markdown]
# ### Question 16:
#
# What is printed?
# ```
# score = 10
# score = score + 5
# score = score - 3
#
# print(score)
# ```
#
# Store your answer in the variable `your_ans`.

# %%
your_ans = ...

# %%
grader.check("q16")

# %% [markdown]
# ### Question 17:
#
# What is printed?
#
# ```
# x = 5
# y = 10
#
# print(x < y and x == 5 or y < 5)
# ```
#
# Store your answer in the variable `your_ans`.

# %%
your_ans = ...

# %%
grader.check("q17")

# %% [markdown]
# ### Question 18:
#
# What happens when this code executes?
# ```
# x = 10
# y = 0
# result = x / y
# ```
#
# A. SyntaxError <br>
# B. NameError <br>
# C. ZeroDivisionError <br>
# D. Prints 0 <br>
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`

# %%
your_ans = ...

# %%
grader.check("q18")

# %% [markdown]
# ### Question 19:
#
# What is printed?
#
# ```
# x = 10
#
# # Increase x by 5
# x = x + 5
#
# # x = x + 100
#
# print(x)
# ```
#
# A. 10 <br>
# B. 15 <br>
# C. 110 <br>
# D. 115 <br>
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`

# %%
your_ans = ...

# %%
grader.check("q19")

# %% [markdown]
# ### Question 20:
#
# Write a python expression to store the result of the expression $\frac{5 * 6 + 2^5 - 20}{5} $ in a variable `your_ans`.
#
# Please note: You shouldn't calculate this result. You simply write the expressions with correct use of python operators, and let python calculate it for you.

# %%
your_ans = ...
your_ans

# %%
grader.check("q20")

# %% [markdown]
# ### Question 21:
#
# Write a python code to convert 50 pounds into kilograms, and store your result in a variable `your_ans`. One pound is 0.454 kilogram.
#
# Please note: You shouldn't calculate this result. You simply write the expressions with correct use of python operators, and let python calculate it for you.

# %%
your_ans = ...
your_ans

# %%
grader.check("q21")

# %% [markdown]
# # Advance Skills

# %% [markdown]
# ### Question 22:
#
# Body Mass Index (BMI) is a measure of health on weight. It can be calculated by taking your weight in kilograms and dividing, by the square of your health in meters.
# Write a python program to calculate a person's BMI given the height is 50 inches, and weight is 95.5. Note, one pound is 0.45359237 kilograms and one inch is 0.0254 meters.

# %%
POUND_TO_KG = 0.45359237  # Conversion factor from pounds to kilograms
INCH_TO_METER = 0.0254  # Conversion factor from inches to meters

weight_pounds = ...
height_inches = ...

# Convert weight and height. Use the variables defined above rather than inserting the exact values. 
weight_kg = ...
height_m = ...

# Calculate BMI
bmi = ...
bmi

# %%
grader.check("q22")

# %% [markdown]
# ### Question 23:
#
# Suppose September 1 is a Monday. You want to determine what day of the week September 24 falls on.
#
# The days of the week are represented as:
#
# ```
# 0 → Monday
# 1 → Tuesday
# 2 → Wednesday
# 3 → Thursday
# 4 → Friday
# 5 → Saturday
# 6 → Sunday
# ```
#
# Which Python expression can be used to determine the day of the week for September 24?
#
# A. `24 % 7` <br>
# B. `(24 - 1) % 7` <br>
# C. `24 / 7` <br>
# D. `(24 + 1) % 7` <br>
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`

# %%
your_ans = ...

# %%
grader.check("q23")

# %% [markdown]
# ### Question 24:
#
# Write a program that takes investment amount of $1000, annual interest rate of 3.25%, number of years of 1 and displays the future investment value using the following formula:
#
# $futureInvestmentValue = investmentAmount * (1 + monthlyInterestRate)^{numberofYears * 12}$

# %%
# Given values
investment_amount = 1000  # Initial investment amount
annual_interest_rate = 3.25  # Annual interest rate in percentage
number_of_years = 1  # Number of years

monthly_interest_rate = ...
    
# Calculate future investment value
future_investment_value = ...

# Display the result
print(f"The future investment value is: ${future_investment_value:.2f}")

# %%
grader.check("q24")

# %% [markdown]
# ### Question 25:
#
# Consider the following Python code:
#
# ```
# x = 12
# y = 5
#
# # Update x using the remainder operator
# x = x + y % 3
#
# z = x * 2 - y
#
# result = z >= 20 and x != y or y > 10
#
# # z = z + "5"
#
# print(x)
# print(z)
# print(result)
# ```
#
# A.
# ```
# 14
# 23
# True
# ```
# B.
# ```
# 14
# 23
# False
# ```
# C.
# ```
# 13
# 21
# True
# ```
# D.
# ```
# 13
# 21
# False
# ```
# E. The program produces a `TypeError.`
#
# Write your option in `your_ans` variables. Do not remove the double quotes, or else, your test will fail.
#
# For eg: If the answer is option A then your answer variable will look like `your_ans = "A"`
#
# Hint: Please refer to the operator precendence table below to find out which operator gets first precendence over the others for expression evaluation.
# ![Precendence Table](https://miro.medium.com/v2/resize:fit:1286/1*YFEPvz5rHtCn1nmzEcfVAw.jpeg)

# %%
your_ans = ...

# %%
grader.check("q25")
